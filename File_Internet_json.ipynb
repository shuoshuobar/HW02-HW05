# %%
# "This is how you get a file from the internet"
import requests

url = "https://pokeapi.co/api/v2/pokemon/snorlax"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.json() # treat this as json and convert it to dictionary
data
# Out:
# {'abilities': [{'ability': {'name': 'immunity',
#     'url': 'https://pokeapi.co/api/v2/ability/17/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'thick-fat',
#     'url': 'https://pokeapi.co/api/v2/ability/47/'},
#    'is_hidden': False,
#    'slot': 2},
#   {'ability': {'name': 'gluttony',
#     'url': 'https://pokeapi.co/api/v2/ability/82/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 189,
#  'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/143.ogg',
#   'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/143.ogg'},
#  'forms': [{'name': 'snorlax',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/143/'}],
#  'game_indices': [{'game_index': 132,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 132,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 132,
# ...

# %%
data.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'cries', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_abilities', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
data['name']
# Out:
# 'snorlax'

# %%
data['cries'] # data type of data['cries'] is dictionary, unlike when data is already a dictionary
# Out:
# {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/143.ogg',
#  'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/143.ogg'}

# %%
data['cries'].keys()
# Out:
# dict_keys(['latest', 'legacy'])

# %%
data['cries']['latest']
# Out:
# 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/143.ogg'

# %%
# replace
# audio=Audio(url=)
# display

# %%
from IPython.display import Audio

# URL of the audio file
audio_url = 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/143.ogg'

# Play the audio
Audio(url=audio_url, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/143.ogg" type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data['abilities'] # this is a list
# Out:
# [{'ability': {'name': 'immunity',
#    'url': 'https://pokeapi.co/api/v2/ability/17/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'thick-fat',
#    'url': 'https://pokeapi.co/api/v2/ability/47/'},
#   'is_hidden': False,
#   'slot': 2},
#  {'ability': {'name': 'gluttony',
#    'url': 'https://pokeapi.co/api/v2/ability/82/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
len(data['abilities'])
# Out:
# 3

# %%
# When you have a dictionary, do .keys()
# When
# look at the first ability
data['abilities'][0] # this is a dictionary
# Out:
# {'ability': {'name': 'immunity',
#   'url': 'https://pokeapi.co/api/v2/ability/17/'},
#  'is_hidden': False,
#  'slot': 1}

# %%
for ability in data['abilities']:
    print("--------------------------------------------------------------------------------") # to split up
    print(ability) # print out each item of the list of data['abilities'] and each item is a dictionary
# Out:
# --------------------------------------------------------------------------------
# {'ability': {'name': 'immunity', 'url': 'https://pokeapi.co/api/v2/ability/17/'}, 'is_hidden': False, 'slot': 1}
# --------------------------------------------------------------------------------
# {'ability': {'name': 'thick-fat', 'url': 'https://pokeapi.co/api/v2/ability/47/'}, 'is_hidden': False, 'slot': 2}
# --------------------------------------------------------------------------------
# {'ability': {'name': 'gluttony', 'url': 'https://pokeapi.co/api/v2/ability/82/'}, 'is_hidden': True, 'slot': 3}

# %%
for ability in data['abilities']:
    print("---------------------------------------------------------------------") # to split up
    # print(ability)
    print(ability['ability'])
# Out:
# ---------------------------------------------------------------------
# {'name': 'immunity', 'url': 'https://pokeapi.co/api/v2/ability/17/'}
# ---------------------------------------------------------------------
# {'name': 'thick-fat', 'url': 'https://pokeapi.co/api/v2/ability/47/'}
# ---------------------------------------------------------------------
# {'name': 'gluttony', 'url': 'https://pokeapi.co/api/v2/ability/82/'}

# %%
for ability in data['abilities']:
    print("--------") # to split up
    # print(ability)
    # print(ability['ability'])
    print(ability['ability']['name'])
# Out:
# --------
# immunity
# --------
# thick-fat
# --------
# gluttony
